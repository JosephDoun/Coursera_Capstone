# %% [markdown]
# ### Applied Data Science Capstone Lab on Coursera
#
# #### Final course for the completion of the IBM Data Science programme.

# %%
import pandas as pd
import numpy as np

print('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!
